# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data\data.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df.reset_index(drop=True,inplace=True)
df.dropna(inplace=True)

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58        20.75          Low Fat         0.007565  Snack Foods
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1

# %%
price_by_item = df.groupby(['Outlet_Establishment_Year' ,'Item_Fat_Content'])  
x = price_by_item.first()
 
x.loc[1987,'LF']
# Out:
# Item_Identifier                     DRL59
# Item_Weight                         16.75
# Item_Visibility                 0.0212065
# Item_Type                     Hard Drinks
# Item_MRP                          52.0298
# Outlet_Identifier                  OUT013
# Outlet_Size                          High
# Outlet_Location_Type               Tier 3
# Outlet_Type             Supermarket Type1
# Name: (1987, LF), dtype: object

# %%
y = pd.crosstab(df['Outlet_Size'],df['Outlet_Location_Type'],margins=True)
y
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3   All
# Outlet_Size
# High                       0       0     621   621
# Medium                   620       0     618  1238
# Small                    620     620       0  1240
# All                     1240     620    1239  3099

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58        20.75          Low Fat         0.007565  Snack Foods
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1

# %%
z = pd.pivot_table(df,index=['Outlet_Establishment_Year'],values=['Item_MRP'])
z
# Out:
#                              Item_MRP
# Outlet_Establishment_Year
# 1987                       140.681858
# 1997                       138.968874
# 1999                       142.461450
# 2004                       138.084348
# 2009                       139.983201

# %%
z1 = pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type'],values=['Item_MRP'],aggfunc=[np.mean,np.median,min,max,np.std])
z1
# Out:
#                                                                   mean  \
#                                                               Item_MRP
# Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 1987                      High        Tier 3                140.681858
# 1997                      Small       Tier 1                138.968874
# 1999                      Medium      Tier 1                142.461450
# 2004                      Small       Tier 2                138.084348
# 2009                      Medium      Tier 3                139.983201
#
#                                                               median      min  \
#                                                             Item_MRP Item_MRP
# Outlet_Establishment_Year Outlet_Size Outlet_Location_Type
# 1987                      High        Tier 3                142.9786  31.9900
# 1997                      Small       Tier 1                133.4442  32.3900
# ...
